# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
#for making fake data set
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1, noise=20, random_state=13)

# %%
plt.scatter(X,y)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)

print("Coef for LinearRegression",lr.coef_)
print("Intercept for LinearRegression",lr.intercept_)
# Out:
# Coef for LinearRegression [28.12597332]
# Intercept for LinearRegression -2.2710144261783825

# %%
y_pred = lr.predict(X_test)

r2_score(y_test,y_pred)
# Out:
# 0.6345158782661012

# %%
# Gradient Descent implement Step By st
class GDRegressore:
  def __init__(self, learning_rate, epochs):

    self.m = 1
    self.b = 0
    self.lr = learning_rate
    self.epochs = epochs

  def fit(self,X,y):
    #calculate b

    for i in range(self.epochs):
      loss_slop_b = -2*np.sum(y - self.m*X.ravel() - self.b)
      loss_slop_m = -2 * np.sum(y - self.m*X.ravel() - self.b)*X.ravel()

      self.b = self.b - (self.lr * loss_slop_b)
      self.m = self.m - (self.lr * loss_slop_m)


      print(f"m = {self.m}, b = {self.b}")

    def predict(self,X):
      return self.n* X + self.b

# %%
gd = GDRegressore(0.001,50)  #epochs  = 50 and Learning rate = 0.001
gd.fit(X_train,y_train)
# Out:
# m = [1.17016386 0.94297702 1.04554272 0.82907728 0.89179875 0.8763753
#  1.23528769 1.14127378 1.05312922 0.72830167 1.2762082  1.06275115
#  1.23184464 0.86883484 0.96878537 0.80616701 1.03492886 0.9295366
#  0.70519756 0.71072017 0.97017083 1.11120048 0.92134772 0.92806302
#  1.04519708 0.93490395 0.74890079 1.04860779 1.0063883  0.80618396
#  1.06171063 0.73449282 0.94839005 0.93315598 1.01172087 1.00034294
#  0.91894531 0.86759984 1.16084591 1.10349767 0.95444508 1.27925589
#  0.94993774 1.04775476 0.79914288 0.9261694  0.78773842 1.05396235
#  1.10967513 1.07612715 0.91920477 0.88300948 1.003843   1.02084472
#  0.98546298 1.12261005 1.18110033 1.15606215 1.0934575  1.0399255
#  0.96585611 0.98172594 0.91928876 0.80903639 1.11325737 0.89005542
#  1.15006123 1.08914006 1.14071589 1.05518792 0.83659518 1.31395484
#  0.97345148 0.80691407 1.09438493 0.93514349 1.13326016 0.89794138
#  0.93495023 1.21716507], b = -0.1435474581801533
# ...

# %%
import numpy as np

# %%
#  2D array
X = np.array([
    [1,2,3],
    [4,5,6]
])

print("Original array : ")
print(X)
print("Shape :", X.shape)

#flatten using ravel
X_flat = X.ravel()

print("\nFlattened array:")
print(X_flat)
print("Shape:", X_flat.shape)
# Out:
# Original array :
# [[1 2 3]
#  [4 5 6]]
# Shape : (2, 3)
#
# Flattened array:
# [1 2 3 4 5 6]
# Shape: (6,)

# %% [markdown]
# #Re use code and Basic structure for do by me পুরো কাঠামো (fill-in-the-blank ভার্সন)

# %%
#just add ___ this section
class GDRegressor:
    def __init__(self, learning_rate, epochs):
        self.m = ___
        self.b = ___
        self.lr = ___
        self.epochs = ___

    def fit(self, X, y):
        X = X.ravel()
        for i in range(self.epochs):
            loss_slope_b = ___
            loss_slope_m = ___

            self.b = ___
            self.m = ___

    def predict(self, X):
        return ___
